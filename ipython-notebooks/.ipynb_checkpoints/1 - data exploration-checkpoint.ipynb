# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('../data/followers_1.csv')
df1
# Out:
#                  username          id                       full_name
# 0                nakedfog  2935593892                  Nala Brodskaya
# 1             iiirinaaa70  2970063788                           irina
# 2            indira160474  3047490121                             NaN
# 3            natasokolova    56012657                             NaN
# 4                my_nansy   235353106                     nasty.nasty
# 5            98california  2328631300             Fabrica🌞CALIFORNIA
# 6        sunny_anna_angel   418499122                  Anna Fomicheva
# 7          pettiskirt_krd  2233548591  🌹pettiskirt_krd💕 Krasnodar🌹
# 8           dariagelunova   270691911                   Dariagelunova
# 9    anastas_mesheryakova   513232661            Анастасия Мещерякова
# 10     rada_studio_moscow  1004210889     Результативная косметология
# 11        be_a_women_shop  2535544876                        GALLA 23
# ...

# %%
df2 = pd.read_csv('../data/posts_1.csv')
df2
# Out:
#       user_id  loc_latitude  \
# 0   611334517           NaN
# 1   611334517           NaN
# 2   611334517           NaN
# 3   611334517           NaN
# 4   611334517           NaN
# 5   611334517           NaN
# 6   611334517           NaN
# 7   611334517           NaN
# 8   611334517           NaN
# 9   611334517           NaN
# 10  611334517           NaN
# 11  611334517           NaN
# 12  611334517           NaN
# 13  611334517           NaN
# 14  611334517           NaN
# 15  611334517           NaN
# 16  611334517           NaN
# 17  611334517           NaN
# 18  611334517           NaN
# 19  611334517           NaN
#
#                                                  tags  \
# 0   уроки yoga красота фитнес асана дайога dayoga ...
# 1   уроки yoga красота фитнес асана дайога dayoga ...
# 2   уроки yoga красота фитнес асана дайога dayoga ...
# 3                                                 NaN
# 4   уроки yoga красота фитнес асана дайога dayoga ...
# ...
